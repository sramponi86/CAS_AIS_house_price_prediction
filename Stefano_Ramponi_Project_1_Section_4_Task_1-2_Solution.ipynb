# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import warnings
warnings.filterwarnings('ignore')
url = "https://raw.githubusercontent.com/mtsilimos/url/main/houseprices.csv"

dataset = pd.read_csv(url)

# %%
dataset.head()

# %%
dataset.describe()

# %%
dataset.dropna(axis=1, thresh = 700, inplace = True)

# %%
dataset = dataset.fillna(dataset.median(numeric_only=True))

# %%
dataset.head()

# %%
dataset.info()

# %%
numerical_cols = dataset.select_dtypes(exclude=['object']).columns.tolist()

# %%
dataset[numerical_cols] = np.log(dataset[numerical_cols])

# %%
categorical_cols = dataset.select_dtypes(include=['object']).columns.tolist()

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
import numpy as np

# %%
#num_pipeline = make_pipeline(SimpleImputer(missing_values = np.nan, strategy='median'),)

cat_pipeline = make_pipeline(SimpleImputer(missing_values = np.nan, strategy='most_frequent'),)

# %%
combined_pipeline = ColumnTransformer([
    ('cat', cat_pipeline, categorical_cols)
], remainder = 'passthrough')

# %%
transformed_dataset = combined_pipeline.fit_transform(dataset)

# %%
feature_names = combined_pipeline.get_feature_names_out()
intermediate_dataset = pd.DataFrame(transformed_dataset, columns = feature_names)
intermediate_dataset.head()
# Out:
#   cat__MSZoning cat__Street cat__LotShape cat__LandContour cat__Utilities  \
# 0            RL        Pave           Reg              Lvl         AllPub
# 1            RL        Pave           Reg              Lvl         AllPub
# 2            RL        Pave           IR1              Lvl         AllPub
# 3            RL        Pave           IR1              Lvl         AllPub
# 4            RL        Pave           IR1              Lvl         AllPub
#
#   cat__LotConfig cat__LandSlope cat__Neighborhood cat__Condition1  \
# 0         Inside            Gtl           CollgCr            Norm
# 1            FR2            Gtl           Veenker           Feedr
# 2         Inside            Gtl           CollgCr            Norm
# 3         Corner            Gtl           Crawfor            Norm
# 4            FR2            Gtl           NoRidge            Norm
#
#   cat__Condition2 cat__BldgType cat__HouseStyle cat__RoofStyle cat__RoofMatl  \
# 0            Norm          1Fam          2Story          Gable       CompShg
# 1            Norm          1Fam          1Story          Gable       CompShg
# 2            Norm          1Fam          2Story          Gable       CompShg
# 3            Norm          1Fam          2Story          Gable       CompShg
# 4            Norm          1Fam          2Story          Gable       CompShg
#
#   cat__Exterior1st cat__Exterior2nd cat__ExterQual cat__ExterCond  \
# 0          VinylSd          VinylSd             Gd             TA
# 1          MetalSd          MetalSd             TA             TA
# 2          VinylSd          VinylSd             Gd             TA
# 3          Wd Sdng          Wd Shng             TA             TA
# 4          VinylSd          VinylSd             Gd             TA
#
#   cat__Foundation cat__BsmtQual cat__BsmtCond cat__BsmtExposure  \
# 0           PConc            Gd            TA                No
# 1          CBlock            Gd            TA                Gd
# 2           PConc            Gd            TA                Mn
# 3          BrkTil            TA            Gd                No
# 4           PConc            Gd            TA                Av
#
#   cat__BsmtFinType1 cat__BsmtFinType2 cat__Heating cat__HeatingQC  \
# 0               GLQ               Unf         GasA             Ex
# 1               ALQ               Unf         GasA             Ex
# 2               GLQ               Unf         GasA             Ex
# 3               ALQ               Unf         GasA             Gd
# 4               GLQ               Unf         GasA             Ex
#
#   cat__CentralAir cat__Electrical cat__KitchenQual cat__Functional  \
# 0               Y           SBrkr               Gd             Typ
# 1               Y           SBrkr               TA             Typ
# 2               Y           SBrkr               Gd             Typ
# 3               Y           SBrkr               Gd             Typ
# 4               Y           SBrkr               Gd             Typ
#
#   cat__FireplaceQu cat__GarageType cat__GarageFinish cat__GarageQual  \
# 0               Gd          Attchd               RFn              TA
# 1               TA          Attchd               RFn              TA
# 2               TA          Attchd               RFn              TA
# 3               Gd          Detchd               Unf              TA
# 4               TA          Attchd               RFn              TA
#
#   cat__GarageCond cat__PavedDrive cat__SaleType cat__SaleCondition  \
# 0              TA               Y            WD             Normal
# 1              TA               Y            WD             Normal
# 2              TA               Y            WD             Normal
# 3              TA               Y            WD            Abnorml
# 4              TA               Y            WD             Normal
#
#   remainder__Id remainder__MSSubClass remainder__LotFrontage  \
# 0           0.0              4.094345               4.174387
# 1      0.693147              2.995732               4.382027
# 2      1.098612              4.094345               4.219508
# 3      1.386294              4.248495               4.094345
# 4      1.609438              4.094345               4.430817
#
#   remainder__LotArea remainder__OverallQual remainder__OverallCond  \
# 0           9.041922                1.94591               1.609438
# 1           9.169518               1.791759               2.079442
# 2           9.328123                1.94591               1.609438
# 3           9.164296                1.94591               1.609438
# 4           9.565214               2.079442               1.609438
#
#   remainder__YearBuilt remainder__YearRemodAdd remainder__MasVnrArea  \
# 0             7.602401                7.602401              5.278115
# 1              7.58883                 7.58883                  -inf
# 2             7.601402                7.601902              5.087596
# 3             7.557473                7.585789                  -inf
# 4             7.600902                7.600902              5.857933
#
#   remainder__BsmtFinSF1 remainder__BsmtFinSF2 remainder__BsmtUnfSF  \
# 0              6.559615                  -inf             5.010635
# 1               6.88551                  -inf             5.648974
# 2              6.186209                  -inf             6.073045
# 3              5.375278                  -inf             6.291569
# 4              6.484635                  -inf             6.194405
#
#   remainder__TotalBsmtSF remainder__1stFlrSF remainder__2ndFlrSF  \
# 0                6.75227             6.75227            6.749931
# 1               7.140453            7.140453                -inf
# 2               6.824374            6.824374            6.763885
# 3               6.628041            6.867974            6.628041
# 4                7.04316             7.04316            6.959399
#
#   remainder__LowQualFinSF remainder__GrLivArea remainder__BsmtFullBath  \
# 0                    -inf             7.444249                     0.0
# 1                    -inf             7.140453                    -inf
# 2                    -inf             7.487734                     0.0
# 3                    -inf             7.448334                     0.0
# 4                    -inf             7.695303                     0.0
#
#   remainder__BsmtHalfBath remainder__FullBath remainder__HalfBath  \
# 0                    -inf            0.693147                 0.0
# 1                     0.0            0.693147                -inf
# 2                    -inf            0.693147                 0.0
# 3                    -inf                 0.0                -inf
# 4                    -inf            0.693147                 0.0
#
#   remainder__BedroomAbvGr remainder__KitchenAbvGr remainder__TotRmsAbvGrd  \
# 0                1.098612                     0.0                2.079442
# 1                1.098612                     0.0                1.791759
# 2                1.098612                     0.0                1.791759
# 3                1.098612                     0.0                 1.94591
# 4                1.386294                     0.0                2.197225
#
#   remainder__Fireplaces remainder__GarageYrBlt remainder__GarageCars  \
# 0                  -inf               7.602401              0.693147
# 1                   0.0                7.58883              0.693147
# 2                   0.0               7.601402              0.693147
# 3                   0.0               7.599902              1.098612
# 4                   0.0               7.600902              1.098612
#
#   remainder__GarageArea remainder__WoodDeckSF remainder__OpenPorchSF  \
# 0              6.306275                  -inf               4.110874
# 1              6.131226              5.697093                   -inf
# 2              6.410175                  -inf                3.73767
# 3              6.464588                  -inf               3.555348
# 4              6.728629              5.257495               4.430817
#
#   remainder__EnclosedPorch remainder__3SsnPorch remainder__ScreenPorch  \
# 0                     -inf                 -inf                   -inf
# 1                     -inf                 -inf                   -inf
# 2                     -inf                 -inf                   -inf
# 3                 5.605802                 -inf                   -inf
# 4                     -inf                 -inf                   -inf
#
#   remainder__PoolArea remainder__MiscVal remainder__MoSold remainder__YrSold  \
# 0                -inf               -inf          0.693147          7.604894
# 1                -inf               -inf          1.609438          7.604396
# 2                -inf               -inf          2.197225          7.604894
# 3                -inf               -inf          0.693147          7.603898
# 4                -inf               -inf          2.484907          7.604894
#
#   remainder__SalePrice
# 0            12.247694
# 1            12.109011
# 2            12.317167
# 3            11.849398
# 4            12.429216

# %%
categorical_cols = intermediate_dataset.select_dtypes(include=['object']).columns.tolist()

# %%
# !pip install category_encoders
from category_encoders import TargetEncoder
encoder = TargetEncoder()
# Out:
# Requirement already satisfied: category_encoders in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from category_encoders) (1.26.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from category_encoders) (2.1.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\diabomba\anaconda3\envs\eth_cas_ais_2024\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.1)

# %%
from sklearn.model_selection import train_test_split

X = intermediate_dataset['remainder__OverallQual']#.drop(columns=['remainder__SalePrice'])
y = intermediate_dataset['remainder__SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X_train = encoder.fit_transform(X_train, y_train)
X_test = encoder.transform(X_test)
X_train.head()
# Out:
#      remainder__OverallQual
# 1390              12.219105
# 1394              12.219105
# 574               11.775457
# 1280              12.219105
# 221               11.972268

# %%
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(alphas=[0.1, 0.001, 0.0001, 0.005, 1, 0.3, 0.5, 0.8, 10, 20, 50, 100, 150])

ridge_cv.fit(X_train, y_train)

ridge_cv.alpha_

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.1)
ridge.fit(X_train, y_train)
y_pred= ridge.predict(X_test)
r2_score(y_test, y_pred)

#0.5013 score with ridgeCV(alpha 0.005) and OverallQual, GrLivArea, GarageCars, GarageArea as features (see previous exercises). with log and encoder to the specific object features
#0.69 score with ridgeCV(alpha 0.1) and OverallQual as only feature (see previous exercises). with log and encoder to the specific object features

# %%
#lasso cv
from sklearn.linear_model import LassoCV
lasso_cv = LassoCV(alphas=[0.1, 0.001, 0.0001, 0.005, 1, 0.3, 0.5, 0.8, 10, 20, 50, 100, 150])
lasso_cv.fit(X_train, y_train)

lasso_cv.alpha_
# Out:
# 0.0001

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.0001)
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)
r2_score(y_test, y_pred_lasso)

#0.505 with lasso and all the features, alpha 0.0001
#0.5995 with lasso and only OverAllQual, alpha 0.0001
# Out:
# 0.599510442459291
