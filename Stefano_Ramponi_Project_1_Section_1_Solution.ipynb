# %% [markdown]
# # Project 1 - Section 1
#
# import pandas and dataset for house proces

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mtsilimos/url/main/houseprices.csv"

dataset = pd.read_csv(url)

# %% [markdown]
# # Fulfill task 1
# displaying first five rows of the dataset

# %%
#task 1
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Fulfill task 2
# Print the dimensions of your pandas dataframe

# %%
#task 2
dataset.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Fulfill task 3
# Check useful information about your pandas dataframe

# %%
#task 3
dataset.info()
dataset.describe()
dataset.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # Fulfill task 4
# Select the columns ‘Street’ and ‘Condition1’ from your pandas dataframe

# %%
#task 4
dataset[["Street", "Condition1"]].head()
# Out:
#   Street Condition1
# 0   Pave       Norm
# 1   Pave      Feedr
# 2   Pave       Norm
# 3   Pave       Norm
# 4   Pave       Norm

# %% [markdown]
# # Fulfill task 5
# Select all rows between row 10 and row 30 from your pandas dataframe

# %%
#task 5
dataset.iloc[10:30]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 13  14          20       RL         91.0    10652   Pave   NaN      IR1
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 17  18          90       RL         72.0    10791   Pave   NaN      Reg
# 18  19          20       RL         66.0    13695   Pave   NaN      Reg
# 19  20          20       RL         70.0     7560   Pave   NaN      Reg
# 20  21          60       RL        101.0    14215   Pave   NaN      IR1
# 21  22          45       RM         57.0     7449   Pave  Grvl      Reg
# ...

# %% [markdown]
# # Fulfill task 6
# Sort your pandas dataframe by the columns ‘YrSold’ and ‘SaleType’

# %%
#task 6
dataset.sort_values(by =['YrSold', 'SaleType'], ignore_index = True, inplace = True)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      203          50       RL         50.0     7000   Pave   NaN      Reg
# 1      558          50  C (all)         60.0    11040   Pave   NaN      Reg
# 2      702          20       RL         80.0     9600   Pave   NaN      Reg
# 3      772          20       RL         67.0     8877   Pave   NaN      Reg
# 4      997          20       RL          NaN    10659   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1456  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1457  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459  1459          20       RL         68.0     9717   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Fulfill task 7
# Filter your pandas dataframe by the string value 'Grvl' in the column 'Alley'

# %%
#task 7
dataset[dataset['Alley'].isin(['Grvl'])]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 92     218          70       RM         57.0     9906   Pave  Grvl      Reg
# 97     247         190       RM         69.0     9142   Pave  Grvl      Reg
# 112    315          70       RM         60.0     9600   Pave  Grvl      Reg
# 156    597          70       RM         60.0     3600   Pave  Grvl      Reg
# 163    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 168    677          70       RM         60.0     9600   Pave  Grvl      Reg
# 192    815          50       RL         45.0     8248   Pave  Grvl      Reg
# 203    897          30       RM         50.0     8765   Pave  Grvl      Reg
# 237   1077          50       RL         60.0    10800   Pave  Grvl      Reg
# 258   1184          30       RL         60.0    10800   Pave  Grvl      Reg
# 291   1338          30       RM        153.0     4118   Pave  Grvl      IR1
# ...

# %% [markdown]
# # Fulfilll task 8
# Filter your pandas dataframe with the column SalePrice containing values only more than 200.000

# %%
#task 8
dataset[dataset['SalePrice'] > 200000 ]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 9       12          60       RL         85.0    11924   Pave   NaN      IR1
# 10      21          60       RL        101.0    14215   Pave   NaN      IR1
# 11      59          60       RL         66.0    13682   Pave   NaN      IR2
# 14     160          60       RL        134.0    19378   Pave   NaN      IR1
# 16     221          20       RL         73.0     8990   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1443  1354          50       RL         56.0    14720   Pave   NaN      IR1
# 1446  1366          60       FV          NaN     7500   Pave   NaN      Reg
# 1447  1370          20       RL         48.0    10635   Pave   NaN      IR2
# 1457  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Fulfill task 9
# Visualise the relationship between the variables ‘YrSold’ and ‘SalePrice’ with a catplot. Set the parameter ‘kind’ to bar

# %%
#task 9
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(data = dataset, x = 'YrSold', y='SalePrice', kind = 'bar', height = 5, aspect = 1.5)
# Out:
# C:\Users\diabomba\anaconda3\envs\ETH_CAS_AIS_2024\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\diabomba\anaconda3\envs\ETH_CAS_AIS_2024\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\diabomba\anaconda3\envs\ETH_CAS_AIS_2024\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
